# %%
import requests
from bs4 import BeautifulSoup

subject = 'Wikipedia:List of controversial issues'
url = "https://en.wikipedia.org/w/api.php?action=parse&format=json&page=Wikipedia:List_of_controversial_issues&section=1&prop=text"

response = requests.get(url)
data = response.json()

type(data["parse"]["text"]["*"])
soup = BeautifulSoup(data["parse"]["text"]["*"], 'html.parser')

# topics = []
# for link in soup.find_all('a'):
#     topics.append(link.get('title'))
#
# with open("../data/controversial_topics_.txt", "w") as f:
#     for i in topics[18:]:
#         f.write(str(i))
#         f.write("\n")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [142], in <cell line: 10>()
#       7 response = requests.get(url)
#       8 data = response.json()
# ---> 10 type(data["parse"]["text"]["*"])
#      11 soup = BeautifulSoup(data["parse"]["text"]["*"], 'html.parser')
#
# KeyError: 'parse'

# %%
soup
# Out:
# <div class="mw-parser-output"><div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Categories_of_past_controversial_issues"><span class="tocnumber">1</span> <span class="toctext">Categories of past controversial issues</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Politics_and_economics"><span class="tocnumber">1.1</span> <span class="toctext">Politics and economics</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#History"><span class="tocnumber">1.2</span> <span class="toctext">History</span></a></li>
# ...

# %%
import requests
from bs4 import BeautifulSoup

subject = 'Wikipedia:List of controversial issues'
url = "https://en.wikipedia.org/w/api.php?action=parse&format=json&page=Wikipedia:List_of_political_ideologies&section=1&prop=text"

response = requests.get(url)
data = response.json()
BeautifulSoup(data, 'html.parser')


# type(data["parse"]["text"]["*"])
# soup = BeautifulSoup(data["parse"]["text"]["*"], 'html.parser')



# topics = []
# for link in soup.find_all('a'):
#     topics.append(link.get('title'))
#
# with open("../data/controversial_topics_.txt", "w") as f:
#     for i in topics[18:]:
#         f.write(str(i))
#         f.write("\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [139], in <cell line: 9>()
#       7 response = requests.get(url)
#       8 data = response.json()
# ----> 9 BeautifulSoup(data, 'html.parser')
#
# File ~/PycharmProjects/countaBot/venv/lib/python3.9/site-packages/bs4/__init__.py:326, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     324 rejections = []
#     325 success = False
# --> 326 for (self.markup, self.original_encoding, self.declared_html_encoding,
#     327  self.contains_replacement_characters) in (
#     328      self.builder.prepare_markup(
#     329          markup, from_encoding, exclude_encodings=exclude_encodings)):
#     330     self.reset()
#     331     self.builder.initialize_soup(self)
#
# ...
